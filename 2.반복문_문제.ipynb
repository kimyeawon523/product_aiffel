# %% [markdown]
# 별을 찍자! : 사용자 입력을 받아 해당 수만큼 별을 찍어보세요.

# %%
user_input = int(input("찍을 별의 높이 선택"))

# %%
# Out:
# *****
# *****
# *****
# *****
# *****

# %%
# Out:
# *
# **
# ***
# ****
# *****

# %%
# Out:
# *****
# ****
# ***
# **
# *

# %%
# Out:
#     *
#    ***
#   *****
#  *******
# *********
#     *
#    ***
#   *****
#  *******
# *********
