# %% [markdown]
# 함수 문제 : 자판기를 만들어보자
# 다음의 기능들을 각 함수로 만들어 자판기의 기능을 하는 프로그램을 만들어보자
# 1. 출력창만 보여주는 print_menu()함수
# 2. 사용자의 입력을 받는 user_input()함수
# 3. 사용자의 입력을 확인하여 자판기의 음료를 출력하거나 -1을 입력받았으면 종료하는 print_drink()함수
#
# - 작동 흐름
# flowchart TD
# ```
# 메뉴 출력 ──► 입력 받기 ──► [-1?] ──No──► 음료 출력 ──🔄
#                             │
#                            Yes
#                             │
#                        "종료합니다" ──► 끝
# ```

# %%
def print_menu():

# %%
def user_input():

# %%
def print_drink(user_input,drink_list):

# %%
drink_list = ['코카콜라','코카콜라 제로','펩시','펩시 제로']
# Out:
# ------------------------
# 1번 코카콜라
# 2번 코카콜라 제로
# 3번 펩시
# 4번 펩시 제로
# -1번 종료
# ------------------------
# 코카콜라 제로를 뽑습니다!
# ------------------------
# 1번 코카콜라
# 2번 코카콜라 제로
# 3번 펩시
# 4번 펩시 제로
# -1번 종료
# ------------------------
# 종료합니다.
